# %% [markdown]
# # 03 — Treinamento dos Modelos e GridSearchCV
#
# Treina Random Forest, AdaBoost e XGBoost. Otimiza hiperparâmetros com GridSearchCV.

# %%
import sys
sys.path.append('..')

import joblib
from src.models import (
    criar_random_forest, criar_adaboost, criar_xgboost,
    PARAMS_RANDOM_FOREST, PARAMS_ADABOOST, PARAMS_XGBOOST,
    otimizar_modelo, salvar_modelo
)

# %%
# Carregar dados pré-processados (gerados no notebook 02)
# X_train, X_test, y_train, y_test = joblib.load('../data/processed/splits.joblib')

# %%
# ── Random Forest ────────────────────────────────────────────
# rf = criar_random_forest()
# grid_rf = otimizar_modelo(rf, PARAMS_RANDOM_FOREST, X_train, y_train)
# salvar_modelo(grid_rf.best_estimator_, '../results/metrics/rf_best.joblib')

# %%
# ── AdaBoost ─────────────────────────────────────────────────
# ab = criar_adaboost()
# grid_ab = otimizar_modelo(ab, PARAMS_ADABOOST, X_train, y_train)
# salvar_modelo(grid_ab.best_estimator_, '../results/metrics/ab_best.joblib')

# %%
# ── XGBoost ──────────────────────────────────────────────────
# xgb = criar_xgboost()
# grid_xgb = otimizar_modelo(xgb, PARAMS_XGBOOST, X_train, y_train)
# salvar_modelo(grid_xgb.best_estimator_, '../results/metrics/xgb_best.joblib')
