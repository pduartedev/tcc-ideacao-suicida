# %% [markdown]
# # 04 — Avaliação e Comparação dos Modelos
#
# Calcula métricas, plota matrizes de confusão, curvas ROC e compara os classificadores.

# %%
import sys
sys.path.append('..')

import joblib
from src.evaluate import (
    calcular_metricas, relatorio_completo,
    plotar_matriz_confusao, plotar_curva_roc,
    comparar_modelos, salvar_metricas
)

# %%
# Carregar dados e modelos
# X_train, X_test, y_train, y_test = joblib.load('../data/processed/splits.joblib')
# rf  = joblib.load('../results/metrics/rf_best.joblib')
# ab  = joblib.load('../results/metrics/ab_best.joblib')
# xgb = joblib.load('../results/metrics/xgb_best.joblib')

# modelos = {'Random Forest': rf, 'AdaBoost': ab, 'XGBoost': xgb}

# %%
# Avaliação de cada modelo
# resultados = {}
# for nome, modelo in modelos.items():
#     y_pred  = modelo.predict(X_test)
#     y_proba = modelo.predict_proba(X_test)[:, 1]
#     relatorio_completo(y_test, y_pred, nome)
#     resultados[nome] = calcular_metricas(y_test, y_pred, y_proba)
#     plotar_matriz_confusao(y_test, y_pred, nome)
#     plotar_curva_roc(y_test, y_proba, nome)

# %%
# Comparar todos os modelos em um gráfico
# comparar_modelos(resultados)

# Salvar métricas em JSON
# salvar_metricas(resultados)
